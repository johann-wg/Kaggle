# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('/users/jjong/desktop/vscode/src/Hotel_Reviews.csv')
data.head()
# Out:
#                                        Hotel_Address  \
# 0   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 1   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 2   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 3   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 4   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
#
#    Additional_Number_of_Scoring Review_Date  Average_Score   Hotel_Name  \
# 0                           194    8/3/2017            7.7  Hotel Arena
# 1                           194    8/3/2017            7.7  Hotel Arena
# 2                           194   7/31/2017            7.7  Hotel Arena
# 3                           194   7/31/2017            7.7  Hotel Arena
# 4                           194   7/24/2017            7.7  Hotel Arena
#
#   Reviewer_Nationality                                    Negative_Review  \
# 0              Russia    I am so angry that i made this post available...
# 1             Ireland                                         No Negative
# 2           Australia    Rooms are nice but for elderly a bit difficul...
# 3      United Kingdom    My room was dirty and I was afraid to walk ba...
# 4         New Zealand    You When I booked with your company on line y...
#
#    Review_Total_Negative_Word_Counts  Total_Number_of_Reviews  \
# 0                                397                     1403
# 1                                  0                     1403
# 2                                 42                     1403
# 3                                210                     1403
# 4                                140                     1403
#
#                                      Positive_Review  \
# 0   Only the park outside of the hotel was beauti...
# 1   No real complaints the hotel was great great ...
# 2   Location was good and staff were ok It is cut...
# 3   Great location in nice surroundings the bar a...
# 4    Amazing location and building Romantic setting
#
#    Review_Total_Positive_Word_Counts  \
# 0                                 11
# 1                                105
# 2                                 21
# 3                                 26
# 4                                  8
#
#    Total_Number_of_Reviews_Reviewer_Has_Given  Reviewer_Score  \
# 0                                           7             2.9
# 1                                           7             7.5
# 2                                           9             7.1
# 3                                           1             3.8
# 4                                           3             6.7
#
#                                                 Tags days_since_review  \
# 0  [' Leisure trip ', ' Couple ', ' Duplex Double...            0 days
# 1  [' Leisure trip ', ' Couple ', ' Duplex Double...            0 days
# 2  [' Leisure trip ', ' Family with young childre...            3 days
# 3  [' Leisure trip ', ' Solo traveler ', ' Duplex...            3 days
# 4  [' Leisure trip ', ' Couple ', ' Suite ', ' St...           10 days
#
#          lat       lng
# 0  52.360576  4.915968
# 1  52.360576  4.915968
# 2  52.360576  4.915968
# 3  52.360576  4.915968
# 4  52.360576  4.915968

# %%
data['Hotel_Address'].nunique()
# Out:
# 1493

# %%
df = data.drop(['lat', 'lng'], axis=1)

# %%
x1 = df['Negative_Review'].values
y1 = df['Review_Total_Negative_Word_Counts'].values
x2 = df['Positive_Review'].values
y2 = df['Review_Total_Positive_Word_Counts'].values

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

tokenizer = Tokenizer()
tokenizer.fit_on_texts(x1)
tokenizer.fit_on_texts(x2)

# %%
tokenizer.word_index
# Out:
# {'the': 1,
#  'and': 2,
#  'was': 3,
#  'to': 4,
#  'a': 5,
#  'room': 6,
#  'in': 7,
#  'very': 8,
#  'no': 9,
#  'staff': 10,
#  'of': 11,
#  'for': 12,
#  'location': 13,
#  'hotel': 14,
#  'is': 15,
#  'i': 16,
#  'we': 17,
#  'it': 18,
#  'were': 19,
#  'not': 20,
#  'breakfast': 21,
#  'good': 22,
#  'negative': 23,
#  'with': 24,
#  'great': 25,
#  'but': 26,
#  'on': 27,
#  'at': 28,
#  'friendly': 29,
#  't': 30,
#  'had': 31,
#  'from': 32,
#  'helpful': 33,
#  'bed': 34,
#  'nice': 35,
#  'that': 36,
#  'clean': 37,
#  'rooms': 38,
#  'have': 39,
#  'you': 40,
#  'as': 41,
#  'there': 42,
#  'this': 43,
#  'so': 44,
#  'our': 45,
#  'comfortable': 46,
#  'excellent': 47,
#  'all': 48,
#  'my': 49,
#  'are': 50,
#  'small': 51,
#  'they': 52,
#  'be': 53,
#  'would': 54,
#  'stay': 55,
#  'nothing': 56,
#  'service': 57,
#  'really': 58,
#  'bathroom': 59,
#  'which': 60,
#  'out': 61,
#  'could': 62,
#  'when': 63,
#  'one': 64,
#  'too': 65,
#  'us': 66,
#  'bar': 67,
#  'only': 68,
#  'lovely': 69,
#  'an': 70,
#  'everything': 71,
#  'positive': 72,
#  'close': 73,
#  's': 74,
#  'also': 75,
#  'shower': 76,
#  'like': 77,
#  'station': 78,
#  'night': 79,
#  'just': 80,
#  'reception': 81,
#  'if': 82,
#  'well': 83,
#  'bit': 84,
#  'didn': 85,
#  'or': 86,
#  'little': 87,
#  'get': 88,
#  'perfect': 89,
#  'more': 90,
#  'by': 91,
#  'food': 92,
#  'time': 93,
#  'view': 94,
#  'area': 95,
#  'me': 96,
#  'walk': 97,
#  'check': 98,
#  'up': 99,
#  'been': 100,
#  'did': 101,
#  'day': 102,
#  'quiet': 103,
#  'price': 104,
#  'restaurant': 105,
#  'can': 106,
#  'facilities': 107,
#  'free': 108,
#  'even': 109,
#  'amazing': 110,
#  'coffee': 111,
#  'london': 112,
#  'comfy': 113,
#  'beds': 114,
#  'some': 115,
#  'about': 116,
#  'again': 117,
#  'floor': 118,
#  'city': 119,
#  '2': 120,
#  'next': 121,
#  'wifi': 122,
#  'water': 123,
#  'after': 124,
#  'much': 125,
#  'quite': 126,
#  'expensive': 127,
#  'will': 128,
#  'metro': 129,
#  'back': 130,
#  'than': 131,
#  'modern': 132,
#  'other': 133,
#  'made': 134,
#  'size': 135,
#  'big': 136,
#  'poor': 137,
#  'air': 138,
#  'fantastic': 139,
#  'what': 140,
#  'place': 141,
#  'easy': 142,
#  'better': 143,
#  'around': 144,
#  'door': 145,
#  'near': 146,
#  'pool': 147,
#  'spacious': 148,
#  'money': 149,
#  'central': 150,
#  'extremely': 151,
#  'two': 152,
#  'wasn': 153,
#  'stayed': 154,
#  'hot': 155,
#  'got': 156,
#  '5': 157,
#  'do': 158,
#  'noisy': 159,
#  'work': 160,
#  'value': 161,
#  'beautiful': 162,
#  'tea': 163,
#  'restaurants': 164,
#  'old': 165,
#  'parking': 166,
#  'noise': 167,
#  'booking': 168,
#  'best': 169,
#  'first': 170,
#  'street': 171,
#  'minutes': 172,
#  'need': 173,
#  'front': 174,
#  'your': 175,
#  'loved': 176,
#  'people': 177,
#  'go': 178,
#  'over': 179,
#  'walking': 180,
#  '3': 181,
#  'enough': 182,
#  '4': 183,
#  'booked': 184,
#  'extra': 185,
#  'asked': 186,
#  'use': 187,
#  'tube': 188,
#  'away': 189,
#  'morning': 190,
#  'every': 191,
#  'any': 192,
#  'outside': 193,
#  'has': 194,
#  'large': 195,
#  'being': 196,
#  'definitely': 197,
#  'off': 198,
#  'right': 199,
#  'bad': 200,
#  'quality': 201,
#  'couldn': 202,
#  'far': 203,
#  'desk': 204,
#  'because': 205,
#  'should': 206,
#  'double': 207,
#  'window': 208,
#  'here': 209,
#  '10': 210,
#  'them': 211,
#  'cold': 212,
#  'way': 213,
#  'where': 214,
#  'most': 215,
#  'told': 216,
#  'down': 217,
#  'tv': 218,
#  'always': 219,
#  'centre': 220,
#  'their': 221,
#  'recommend': 222,
#  'bath': 223,
#  'train': 224,
#  'distance': 225,
#  'before': 226,
#  'access': 227,
#  'open': 228,
#  'many': 229,
#  'hotels': 230,
#  'who': 231,
#  'though': 232,
#  'super': 233,
#  'available': 234,
#  'into': 235,
#  'choice': 236,
#  'especially': 237,
#  'wonderful': 238,
#  'then': 239,
#  'convenient': 240,
#  'high': 241,
#  'park': 242,
#  'although': 243,
#  'liked': 244,
#  'make': 245,
#  'space': 246,
#  'sleep': 247,
#  'pay': 248,
#  'feel': 249,
#  'star': 250,
#  'find': 251,
#  'located': 252,
#  'early': 253,
#  'pleasant': 254,
#  'decor': 255,
#  'lot': 256,
#  'needed': 257,
#  '1': 258,
#  'few': 259,
#  'don': 260,
#  'building': 261,
#  'pillows': 262,
#  'still': 263,
#  'center': 264,
#  'went': 265,
#  'etc': 266,
#  'working': 267,
#  'arrived': 268,
#  'warm': 269,
#  'experience': 270,
#  'top': 271,
#  'paid': 272,
#  'long': 273,
#  'help': 274,
#  'new': 275,
#  'welcoming': 276,
#  'during': 277,
#  'arrival': 278,
#  'problem': 279,
#  'however': 280,
#  'given': 281,
#  'lobby': 282,
#  'overall': 283,
#  'its': 284,
#  'ok': 285,
#  'standard': 286,
#  'times': 287,
#  'bedroom': 288,
#  'thing': 289,
#  'polite': 290,
#  'left': 291,
#  'main': 292,
#  'felt': 293,
#  'having': 294,
#  'included': 295,
#  'think': 296,
#  'never': 297,
#  'buffet': 298,
#  'toilet': 299,
#  'without': 300,
#  'hard': 301,
#  'late': 302,
#  'needs': 303,
#  'took': 304,
#  'design': 305,
#  'same': 306,
#  'he': 307,
#  'take': 308,
#  'bus': 309,
#  'drinks': 310,
#  'guests': 311,
#  'kind': 312,
#  'see': 313,
#  'tiny': 314,
#  'paris': 315,
#  'spa': 316,
#  'lots': 317,
#  'windows': 318,
#  'days': 319,
#  'found': 320,
#  'said': 321,
#  'slow': 322,
#  'tram': 323,
#  'going': 324,
#  'another': 325,
#  'put': 326,
#  'suite': 327,
#  'nearby': 328,
#  'within': 329,
#  'conditioning': 330,
#  'car': 331,
#  'side': 332,
#  'airport': 333,
#  'underground': 334,
#  'come': 335,
#  'upgrade': 336,
#  'short': 337,
#  'evening': 338,
#  'want': 339,
#  'single': 340,
#  'english': 341,
#  'fresh': 342,
#  'how': 343,
#  'lift': 344,
#  'ask': 345,
#  'charge': 346,
#  'nights': 347,
#  'card': 348,
#  'cleanliness': 349,
#  'ever': 350,
#  'full': 351,
#  'anything': 352,
#  'upgraded': 353,
#  'towels': 354,
#  'staying': 355,
#  'lounge': 356,
#  'dirty': 357,
#  'minute': 358,
#  'shopping': 359,
#  'superb': 360,
#  'such': 361,
#  'welcome': 362,
#  've': 363,
#  'while': 364,
#  'road': 365,
#  'due': 366,
#  'gave': 367,
#  '15': 368,
#  'both': 369,
#  'light': 370,
#  'views': 371,
#  'visit': 372,
#  'rather': 373,
#  'she': 374,
#  'professional': 375,
#  'expected': 376,
#  'through': 377,
#  'happy': 378,
#  'came': 379,
#  'provided': 380,
#  'brilliant': 381,
#  'wanted': 382,
#  'wait': 383,
#  'cost': 384,
#  'special': 385,
#  'comfort': 386,
#  'busy': 387,
#  'selection': 388,
#  'am': 389,
#  'attentive': 390,
#  'public': 391,
#  'complimentary': 392,
#  'uncomfortable': 393,
#  'offered': 394,
#  'each': 395,
#  '30': 396,
#  'worth': 397,
#  'things': 398,
#  'until': 399,
#  'transport': 400,
#  'cleaning': 401,
#  'luggage': 402,
#  'enjoyed': 403,
#  'second': 404,
#  'hear': 405,
#  'internet': 406,
#  'used': 407,
#  'stop': 408,
#  'making': 409,
#  'atmosphere': 410,
#  'concierge': 411,
#  'mini': 412,
#  'able': 413,
#  'gym': 414,
#  'efficient': 415,
#  'looked': 416,
#  'min': 417,
#  '20': 418,
#  'amsterdam': 419,
#  'person': 420,
#  'absolutely': 421,
#  'places': 422,
#  'taxi': 423,
#  'know': 424,
#  'com': 425,
#  'per': 426,
#  'smell': 427,
#  'rude': 428,
#  'fine': 429,
#  'change': 430,
#  'machine': 431,
#  'say': 432,
#  'fridge': 433,
#  'd': 434,
#  'birthday': 435,
#  'shops': 436,
#  'tired': 437,
#  'checked': 438,
#  'receptionist': 439,
#  'eat': 440,
#  'family': 441,
#  'drink': 442,
#  'whole': 443,
#  'mins': 444,
#  'difficult': 445,
#  'hours': 446,
#  'plenty': 447,
#  'trip': 448,
#  'roof': 449,
#  'thought': 450,
#  'dinner': 451,
#  'ready': 452,
#  'huge': 453,
#  'attractions': 454,
#  'look': 455,
#  'sure': 456,
#  'different': 457,
#  'looking': 458,
#  'terrace': 459,
#  'fault': 460,
#  'pretty': 461,
#  'across': 462,
#  'business': 463,
#  'customer': 464,
#  'fabulous': 465,
#  'last': 466,
#  'end': 467,
#  'delicious': 468,
#  'charged': 469,
#  'limited': 470,
#  'getting': 471,
#  'manager': 472,
#  'kept': 473,
#  'dark': 474,
#  'tower': 475,
#  'safe': 476,
#  'love': 477,
#  'book': 478,
#  'm': 479,
#  'leave': 480,
#  'wall': 481,
#  'balcony': 482,
#  'hour': 483,
#  'issue': 484,
#  'cleaned': 485,
#  'table': 486,
#  'style': 487,
#  'stuff': 488,
#  'return': 489,
#  'ideal': 490,
#  'above': 491,
#  're': 492,
#  'seemed': 493,
#  'areas': 494,
#  'order': 495,
#  'fact': 496,
#  'thank': 497,
#  'something': 498,
#  'broken': 499,
#  'phone': 500,
#  'menu': 501,
#  'couple': 502,
#  'highly': 503,
#  'barcelona': 504,
#  'closed': 505,
#  'furniture': 506,
#  'expect': 507,
#  'cool': 508,
#  'basic': 509,
#  'done': 510,
#  'con': 511,
#  'options': 512,
#  'offer': 513,
#  'touch': 514,
#  'variety': 515,
#  'soft': 516,
#  'properly': 517,
#  'inside': 518,
#  'heating': 519,
#  'almost': 520,
#  'her': 521,
#  'despite': 522,
#  'home': 523,
#  'give': 524,
#  'requested': 525,
#  'swimming': 526,
#  'elevator': 527,
#  'wi': 528,
#  'less': 529,
#  'bars': 530,
#  'bottle': 531,
#  'loud': 532,
#  'checking': 533,
#  'fi': 534,
#  'plus': 535,
#  'glass': 536,
#  'decorated': 537,
#  'walls': 538,
#  'eggs': 539,
#  'property': 540,
#  'executive': 541,
#  'call': 542,
#  'disappointed': 543,
#  'lack': 544,
#  'part': 545,
#  'position': 546,
#  'dated': 547,
#  'accommodating': 548,
#  'twin': 549,
#  'prices': 550,
#  'rooftop': 551,
#  'amenities': 552,
#  'else': 553,
#  'rate': 554,
#  'coming': 555,
#  'terrible': 556,
#  'bigger': 557,
#  'waiting': 558,
#  'between': 559,
#  'request': 560,
#  'kettle': 561,
#  'under': 562,
#  'system': 563,
#  'maybe': 564,
#  'local': 565,
#  'toiletries': 566,
#  'three': 567,
#  'entrance': 568,
#  'corner': 569,
#  'changed': 570,
#  'line': 571,
#  'doors': 572,
#  'once': 573,
#  'disappointing': 574,
#  'someone': 575,
#  'guest': 576,
#  'actually': 577,
#  'travel': 578,
#  '7': 579,
#  'lighting': 580,
#  'housekeeping': 581,
#  'served': 582,
#  'temperature': 583,
#  'sound': 584,
#  'let': 585,
#  'weekend': 586,
#  'euros': 587,
#  'wouldn': 588,
#  'decent': 589,
#  'carpet': 590,
#  'since': 591,
#  'slightly': 592,
#  'town': 593,
#  'stations': 594,
#  'several': 595,
#  'stairs': 596,
#  'called': 597,
#  'mattress': 598,
#  'instead': 599,
#  'move': 600,
#  'n': 601,
#  'tried': 602,
#  'why': 603,
#  'level': 604,
#  '6': 605,
#  'half': 606,
#  'bags': 607,
#  'milk': 608,
#  'itself': 609,
#  'vienna': 610,
#  'connection': 611,
#  'square': 612,
#  'lady': 613,
#  'real': 614,
#  'house': 615,
#  'worked': 616,
#  'later': 617,
#  'twice': 618,
#  'member': 619,
#  'interior': 620,
#  'cooked': 621,
#  'facility': 622,
#  'garden': 623,
#  'keep': 624,
#  'awesome': 625,
#  'middle': 626,
#  'either': 627,
#  'sink': 628,
#  'wine': 629,
#  'equipped': 630,
#  '50': 631,
#  'hair': 632,
#  'key': 633,
#  'euro': 634,
#  'none': 635,
#  'st': 636,
#  'stars': 637,
#  'cosy': 638,
#  'dining': 639,
#  'site': 640,
#  'own': 641,
#  'set': 642,
#  'attention': 643,
#  'fast': 644,
#  '00': 645,
#  'upon': 646,
#  'quick': 647,
#  'helped': 648,
#  'fruit': 649,
#  'bathrooms': 650,
#  'option': 651,
#  'yet': 652,
#  'moved': 653,
#  'stylish': 654,
#  'general': 655,
#  'everyone': 656,
#  'club': 657,
#  'does': 658,
#  'everywhere': 659,
#  'may': 660,
#  'tourist': 661,
#  'particularly': 662,
#  'milan': 663,
#  'services': 664,
#  'priced': 665,
#  'superior': 666,
#  'smaller': 667,
#  'including': 668,
#  'problems': 669,
#  'his': 670,
#  'lifts': 671,
#  'reasonable': 672,
#  'already': 673,
#  '12': 674,
#  'probably': 675,
#  'unfortunately': 676,
#  'point': 677,
#  'year': 678,
#  'hyde': 679,
#  'subway': 680,
#  'easily': 681,
#  'overpriced': 682,
#  'throughout': 683,
#  'weren': 684,
#  'courteous': 685,
#  'ac': 686,
#  'didnt': 687,
#  'together': 688,
#  'continental': 689,
#  'least': 690,
#  'information': 691,
#  'lights': 692,
#  'de': 693,
#  'pricey': 694,
#  'these': 695,
#  'cannot': 696,
#  'rest': 697,
#  'non': 698,
#  'major': 699,
#  'iron': 700,
#  '8': 701,
#  'using': 702,
#  'deal': 703,
#  'nicely': 704,
#  'personal': 705,
#  'doesn': 706,
#  'meal': 707,
#  'try': 708,
#  'low': 709,
#  'tidy': 710,
#  'ground': 711,
#  'average': 712,
#  'king': 713,
#  'cheap': 714,
#  'friends': 715,
#  'must': 716,
#  'hall': 717,
#  'breakfasts': 718,
#  'thanks': 719,
#  'issues': 720,
#  'trouble': 721,
#  'handy': 722,
#  'staffs': 723,
#  'start': 724,
#  'paying': 725,
#  'awful': 726,
#  'possible': 727,
#  'traffic': 728,
#  'four': 729,
#  'river': 730,
#  'relaxing': 731,
#  'proximity': 732,
#  'complain': 733,
#  'turn': 734,
#  'now': 735,
#  'received': 736,
#  'items': 737,
#  'wrong': 738,
#  'outstanding': 739,
#  'curtains': 740,
#  'situated': 741,
#  'except': 742,
#  'credit': 743,
#  'appointed': 744,
#  'head': 745,
#  'children': 746,
#  'choices': 747,
#  'recommended': 748,
#  'bonus': 749,
#  'paddington': 750,
#  'ordered': 751,
#  'channels': 752,
#  'run': 753,
#  'basement': 754,
#  'exceptional': 755,
#  'opened': 756,
#  'appreciated': 757,
#  'looks': 758,
#  'sized': 759,
#  'fan': 760,
#  'provide': 761,
#  'anyone': 762,
#  '24': 763,
#  'longer': 764,
#  'eiffel': 765,
#  'meant': 766,
#  'enjoy': 767,
#  'thin': 768,
#  'round': 769,
#  'construction': 770,
#  'care': 771,
#  'cramped': 772,
#  'kitchen': 773,
#  'stops': 774,
#  'minibar': 775,
#  'number': 776,
#  'designed': 777,
#  'kids': 778,
#  'luxury': 779,
#  'reach': 780,
#  'helpfull': 781,
#  'slept': 782,
#  'checkout': 783,
#  'e': 784,
#  'sauna': 785,
#  'years': 786,
#  'otherwise': 787,
#  'considering': 788,
#  'incredibly': 789,
#  'boutique': 790,
#  'opposite': 791,
#  'might': 792,
#  'sit': 793,
#  'afternoon': 794,
#  'surprise': 795,
#  'music': 796,
#  'young': 797,
#  'those': 798,
#  'control': 799,
#  'museums': 800,
#  'amount': 801,
#  'wife': 802,
#  'leaving': 803,
#  'decoration': 804,
#  'fab': 805,
#  'tasty': 806,
#  'beach': 807,
#  'works': 808,
#  'cafes': 809,
#  'smoking': 810,
#  'makes': 811,
#  'class': 812,
#  'worst': 813,
#  'turned': 814,
#  'floors': 815,
#  'fixed': 816,
#  'wish': 817,
#  'taken': 818,
#  'la': 819,
#  'seem': 820,
#  'complaints': 821,
#  'cozy': 822,
#  'understand': 823,
#  'separate': 824,
#  'minor': 825,
#  'corridor': 826,
#  'informed': 827,
#  'attitude': 828,
#  'facing': 829,
#  'shuttle': 830,
#  'mirror': 831,
#  'trying': 832,
#  'deluxe': 833,
#  'travelling': 834,
#  'choose': 835,
#  'heart': 836,
#  'pictures': 837,
#  'taking': 838,
#  'name': 839,
#  'sheets': 840,
#  'till': 841,
#  'slippers': 842,
#  'quickly': 843,
#  'friendliness': 844,
#  'website': 845,
#  'renovation': 846,
#  'neighborhood': 847,
#  '100': 848,
#  'apart': 849,
#  'walked': 850,
#  'seems': 851,
#  'directly': 852,
#  'seen': 853,
#  'perfectly': 854,
#  'luxurious': 855,
#  'museum': 856,
#  'reservation': 857,
#  'downstairs': 858,
#  'u': 859,
#  'certainly': 860,
#  'sleeping': 861,
#  'sometimes': 862,
#  'reason': 863,
#  'spotless': 864,
#  '9': 865,
#  'sofa': 866,
#  'compared': 867,
#  'snacks': 868,
#  'isn': 869,
#  'daily': 870,
#  'corridors': 871,
#  'beautifully': 872,
#  'transportation': 873,
#  'visiting': 874,
#  'via': 875,
#  'adequate': 876,
#  'deposit': 877,
#  'hand': 878,
#  'whilst': 879,
#  'case': 880,
#  'hilton': 881,
#  'annoying': 882,
#  'condition': 883,
#  'larger': 884,
#  'smile': 885,
#  'asking': 886,
#  'others': 887,
#  'man': 888,
#  'anywhere': 889,
#  'c': 890,
#  'duomo': 891,
#  'oxford': 892,
#  'personnel': 893,
#  '25': 894,
#  'bill': 895,
#  'takes': 896,
#  'cafe': 897,
#  'pillow': 898,
#  'gorgeous': 899,
#  'allowed': 900,
#  'renovated': 901,
#  'week': 902,
#  'simple': 903,
#  'normal': 904,
#  'husband': 905,
#  'v': 906,
#  'plug': 907,
#  'soon': 908,
#  'behind': 909,
#  'totally': 910,
#  'tables': 911,
#  'detail': 912,
#  'world': 913,
#  'generally': 914,
#  'steps': 915,
#  'team': 916,
#  'complained': 917,
#  'added': 918,
#  'sky': 919,
#  'o2': 920,
#  'pressure': 921,
#  'accommodation': 922,
#  'tub': 923,
#  'missing': 924,
#  'cheaper': 925,
#  'partner': 926,
#  'completely': 927,
#  'cake': 928,
#  'mentioned': 929,
#  'flight': 930,
#  'management': 931,
#  'wardrobe': 932,
#  'fire': 933,
#  'standards': 934,
#  'show': 935,
#  'sights': 936,
#  'll': 937,
#  'worn': 938,
#  'additional': 939,
#  'five': 940,
#  'ride': 941,
#  'clear': 942,
#  'sunday': 943,
#  'stunning': 944,
#  'strange': 945,
#  'fully': 946,
#  'please': 947,
#  'details': 948,
#  'overlooking': 949,
#  'immediately': 950,
#  'below': 951,
#  'brought': 952,
#  'daughter': 953,
#  'him': 954,
#  'kensington': 955,
#  'aircon': 956,
#  'empty': 957,
#  'towel': 958,
#  'spot': 959,
#  'horrible': 960,
#  'conditioner': 961,
#  'carpets': 962,
#  'paper': 963,
#  'pm': 964,
#  '11': 965,
#  'shame': 966,
#  'private': 967,
#  'proper': 968,
#  'maintenance': 969,
#  'bread': 970,
#  'perhaps': 971,
#  'anniversary': 972,
#  'canal': 973,
#  'spent': 974,
#  'sightseeing': 975,
#  'heard': 976,
#  'literally': 977,
#  'ended': 978,
#  'customers': 979,
#  'apartment': 980,
#  'security': 981,
#  'type': 982,
#  'bedrooms': 983,
#  'idea': 984,
#  'ceiling': 985,
#  'payment': 986,
#  'accessible': 987,
#  'feeling': 988,
#  'champagne': 989,
#  'charming': 990,
#  'previous': 991,
#  'bacon': 992,
#  'sign': 993,
#  'guy': 994,
#  'enjoyable': 995,
#  'fairly': 996,
#  'alarm': 997,
#  'fair': 998,
#  'clearly': 999,
#  'clothes': 1000,
#  ...}

# %%
x1_tk = tokenizer.texts_to_sequences(x1)
x2_tk = tokenizer.texts_to_sequences(x2)

# %%
max_len1 = max([len(s) for s in x1_tk])
max_len2 = max([len(s) for s in x2_tk])

# %%
x1_sq = pad_sequences(x1_tk, maxlen=max_len1, padding='pre')
x2_sq = pad_sequences(x2_tk, maxlen=max_len2, padding='pre')
x2_sq.shape
# Out:
# (515738, 393)

# %%
vocab_size = len(tokenizer.word_index) + 1
vocab_size
# Out:
# 81295

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(x1_sq, y1, test_size=0.2, shuffle=True, random_state=0)
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (412590, 406) (412590,)
# (103148, 406) (103148,)

# %%
from tensorflow.keras import layers
from tensorflow.keras import Model

# Body
inputs = layers.Input(shape=(max_len1,))
x = layers.Embedding(vocab_size, 64, embeddings_regularizer='l2')(inputs)
x = layers.GRU(units=64, return_sequences=True)(x)
x = layers.GRU(units=64, return_sequences=False)(x)

# header
x = layers.Dense(32, activation='relu')(x)
outputs = layers.Dense(1, activation='linear')(x)  # activation='linear' 생략 가능  

model = Model(inputs=inputs, outputs=outputs)    
model.compile(optimizer='adam', loss='mse')  
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 406)]             0
#
#  embedding (Embedding)       (None, 406, 64)           5202880
#
#  gru (GRU)                   (None, 406, 64)           24960
#
#  gru_1 (GRU)                 (None, 64)                24960
#
#  dense (Dense)               (None, 32)                2080
#
#  dense_1 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 5254913 (20.05 MB)
# Trainable params: 5254913 (20.05 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
from tensorflow.keras.callbacks import EarlyStopping

es_callback = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
history = model.fit(X_train, y_train, batch_size=64, epochs=300, validation_split=0.2, callbacks=[es_callback])
# Out:
# Epoch 1/300
#   43/5158 [..............................] - ETA: 24:16 - loss: 1091.4646
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[32], line 4
#       1 from tensorflow.keras.callbacks import EarlyStopping
#       3 es_callback = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
# ----> 4 history = model.fit(X_train, y_train, batch_size=64, epochs=300, validation_split=0.2, callbacks=[es_callback])
#
# File c:\Users\jjong\Desktop\vscode\CWNU_ICT\tensor\Lib\site-packages\keras\src\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\jjong\Desktop\vscode\CWNU_ICT\tensor\Lib\site-packages\keras\src\engine\training.py:1742, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1734 with tf.profiler.experimental.Trace(
#    1735     "train",
#    1736     epoch_num=epoch,
#    (...)
#    1739     _r=1,
#    1740 ):
#    1741     callbacks.on_train_batch_begin(step)
# -> 1742     tmp_logs = self.train_function(iterator)
#    1743     if data_handler.should_sync:
#    1744         context.async_wait()
#
# File c:\Users\jjong\Desktop\vscode\CWNU_ICT\tensor\Lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\jjong\Desktop\vscode\CWNU_ICT\tensor\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:825, in Function.__call__(self, *args, **kwds)
#     822 compiler = "xla" if self._jit_compile else "nonXla"
#     824 with OptionalXlaContext(self._jit_compile):
# --> 825   result = self._call(*args, **kwds)
#     827 new_tracing_count = self.experimental_get_tracing_count()
#     828 without_tracing = (tracing_count == new_tracing_count)
#
# File c:\Users\jjong\Desktop\vscode\CWNU_ICT\tensor\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:857, in Function._call(self, *args, **kwds)
#     854   self._lock.release()
#     855   # In this case we have created variables on the first call, so we run the
#     856   # defunned version which is guaranteed to never create variables.
# --> 857   return self._no_variable_creation_fn(*args, **kwds)  # pylint: disable=not-callable
#     858 elif self._variable_creation_fn is not None:
#     859   # Release the lock early so that multiple threads can perform the call
#     860   # in parallel.
#     861   self._lock.release()
#
# File c:\Users\jjong\Desktop\vscode\CWNU_ICT\tensor\Lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compiler.py:148, in TracingCompiler.__call__(self, *args, **kwargs)
#     145 with self._lock:
#     146   (concrete_function,
#     147    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# --> 148 return concrete_function._call_flat(
#     149     filtered_flat_args, captured_inputs=concrete_function.captured_inputs)
#
# File c:\Users\jjong\Desktop\vscode\CWNU_ICT\tensor\Lib\site-packages\tensorflow\python\eager\polymorphic_function\monomorphic_function.py:1349, in ConcreteFunction._call_flat(self, args, captured_inputs)
#    1345 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1346 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1347     and executing_eagerly):
#    1348   # No tape is watching; skip to running the function.
# -> 1349   return self._build_call_outputs(self._inference_function(*args))
#    1350 forward_backward = self._select_forward_and_backward_functions(
#    1351     args,
#    1352     possible_gradient_type,
#    1353     executing_eagerly)
#    1354 forward_function, args_with_tangents = forward_backward.forward()
#
# File c:\Users\jjong\Desktop\vscode\CWNU_ICT\tensor\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:196, in AtomicFunction.__call__(self, *args)
#     194 with record.stop_recording():
#     195   if self._bound_context.executing_eagerly():
# --> 196     outputs = self._bound_context.call_function(
#     197         self.name,
#     198         list(args),
#     199         len(self.function_type.flat_outputs),
#     200     )
#     201   else:
#     202     outputs = make_call_op_in_graph(self, list(args))
#
# File c:\Users\jjong\Desktop\vscode\CWNU_ICT\tensor\Lib\site-packages\tensorflow\python\eager\context.py:1457, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1455 cancellation_context = cancellation.context()
#    1456 if cancellation_context is None:
# -> 1457   outputs = execute.execute(
#    1458       name.decode("utf-8"),
#    1459       num_outputs=num_outputs,
#    1460       inputs=tensor_inputs,
#    1461       attrs=attrs,
#    1462       ctx=self,
#    1463   )
#    1464 else:
#    1465   outputs = execute.execute_with_cancellation(
#    1466       name.decode("utf-8"),
#    1467       num_outputs=num_outputs,
#    (...)
#    1471       cancellation_manager=cancellation_context,
#    1472   )
#
# File c:\Users\jjong\Desktop\vscode\CWNU_ICT\tensor\Lib\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:
