# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings(action='ignore')
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False

# %%
train_logs = pd.read_csv('/Users/jjong/desktop/vscode/kaggle_src/linking-writing/train_logs.csv')
train_scores = pd.read_csv('/Users/jjong/desktop/vscode/kaggle_src/linking-writing/train_scores.csv')
test_logs = pd.read_csv('/Users/jjong/desktop/vscode/kaggle_src/linking-writing/test_logs.csv')
sample_submission = pd.read_csv('/Users/jjong/desktop/vscode/kaggle_src/linking-writing/sample_submission.csv')

# %%
train_logs
# Out:
#                id  event_id  down_time  up_time  action_time       activity  \
# 0        001519c8         1       4526     4557           31  Nonproduction
# 1        001519c8         2       4558     4962          404  Nonproduction
# 2        001519c8         3     106571   106571            0  Nonproduction
# 3        001519c8         4     106686   106777           91          Input
# 4        001519c8         5     107196   107323          127          Input
# ...           ...       ...        ...      ...          ...            ...
# 8405893  fff05981      3615    2063944  2064440          496  Nonproduction
# 8405894  fff05981      3616    2064497  2064497            0  Nonproduction
# 8405895  fff05981      3617    2064657  2064765          108        Replace
# 8405896  fff05981      3618    2069186  2069259           73  Nonproduction
# 8405897  fff05981      3619    2070065  2070133           68          Input
#
# ...

# %%
train_logs.groupby('id').sum()
# Out:
#           event_id   down_time     up_time  action_time  \
# id
# 001519c8   3270403  2168798234  2169095477       297243
# 0022f953   3012285  1273271023  1273546414       275391
# 0042269b   8555316  3426641982  3427063183       421201
# 0059420b   1211346  1222211589  1222401185       189596
# 0075873a   3204246  1805499474  1805813176       313702
# ...            ...         ...         ...          ...
# ffb8c745  11231430  3488386746  3488886416       499670
# ffbef7e5   3391710  2192480040  2192694261       214221
# ffccd6fd   4692516  3764472937  3764704517       231580
# ffec5b38   5256903  1869073112  1869362551       289439
# fff05981   6550390  3897099261  3897400496       301235
#
#                                                    activity  \
# id
# 001519c8  NonproductionNonproductionNonproductionInputIn...
# 0022f953  NonproductionNonproductionInputInputInputInput...
# 0042269b  NonproductionNonproductionInputInputInputInput...
# ...

# %%
test_logs
# Out:
#          id  event_id  down_time  up_time  action_time activity down_event  \
# 0  0000aaaa         1     338433   338518           85    Input      Space
# 1  0000aaaa         2     760073   760160           87    Input      Space
# 2  2222bbbb         1     711956   712023           67    Input          q
# 3  2222bbbb         2     290502   290548           46    Input          q
# 4  4444cccc         1     635547   635641           94    Input      Space
# 5  4444cccc         2     184996   185052           56    Input          q
#
#   up_event text_change  cursor_position  word_count
# 0    Space                            0           0
# 1    Space                            1           0
# 2        q           q                0           1
# 3        q           q                1           1
# 4    Space                            0           0
# 5        q           q                1           1

# %%
train_scores
# Out:
#             id  score
# 0     001519c8    3.5
# 1     0022f953    3.5
# 2     0042269b    6.0
# 3     0059420b    2.0
# 4     0075873a    4.0
# ...        ...    ...
# 2466  ffb8c745    3.5
# 2467  ffbef7e5    4.0
# 2468  ffccd6fd    1.5
# 2469  ffec5b38    5.0
# 2470  fff05981    4.0
#
# [2471 rows x 2 columns]
